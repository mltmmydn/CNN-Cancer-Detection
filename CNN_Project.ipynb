# %% [markdown]
# ## Step 1: Brief description of the problem and data
#
# In this project I will make use of a convolutional nueral network (CNN) in order to detect metatstatic cancer in cells. The data used will be from a a (Kaggle Competition)[https://www.kaggle.com/competitions/histopathologic-cancer-detection/overview]. The data are RGB images, with corresponding labels supplied for the training data. I will run my model on the test data to generate models and validate the test accuracy using Kaggle's submission feature.
# The data are split into two binary exlusive classes. The images are of cells that either do or do not have cancer. In total, there are 220,025 training cases. I chose to use 80% for training, and 20% for validation in accordance with the rule of thumb. The  According to the Kaggle listing, the training data, test data, and labels combined consist of a ~7.75 GB file. There will be some duplication of data in the effort of unzipping the file during download, so if your machine experiences lag after loading, a good intermediate step would be to delete the ZIP file after unzipping.
#
# The individual image files are all .tif files of shape (96, 96, 3). According to the Kaggle listing, the training label is assigned as positive if at least one pixel in the center (32, 32) of an image contains tumorous tissue. The rest of the image is provided to enable CNN with padding schemes / convolution stride that eats away at the exterior of the image.
#
# The test dataset consists of unlabeled .tif images. The goal of this project is to predict the labels of those test images with the CNN I will build.
#
# # Step 2: Data Loading, Cleaning, and EDA
#
# First we'll load the necessary libraries. Please ensure that you have these installed on your environment before running this notebook.

# %%
# Load libraries for project
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd
import cv2 # For EDA
from PIL import Image
import sys

# %% [markdown]
# # Data download
#
# Now we will go about loading the data from the [Kaggle competition](https://www.kaggle.com/competitions/histopathologic-cancer-detection/data) into the colab. Please ensure that your current working directory contains the requisite data files for this project.
# Citation: https://towardsdatascience.com/7-ways-to-load-external-data-into-google-colab-7ba73e7d5fc7

# %%
from google.colab import files
uploaded = files.upload() # Please upload your kaggle.json file
# Out:
#      <input type="file" id="files-7c51c8db-f7ea-481f-8102-009fcdb82d97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c51c8db-f7ea-481f-8102-009fcdb82d97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !pwd
# Out:
# /content

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content"
"chmod 600 /content/kaggle.json"
# Out:
# 'chmod 600 /content/kaggle.json'

# %%
# !kaggle competitions download -c histopathologic-cancer-detection
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Downloading histopathologic-cancer-detection.zip to /content
# 100% 6.29G/6.31G [00:28<00:00, 226MB/s]
# 100% 6.31G/6.31G [00:28<00:00, 236MB/s]

# %%
os.listdir(".") #The data have been successfully downloaded. Now we need to unzip.
# Out:
# ['.config',
#  'histopathologic-cancer-detection.zip',
#  'kaggle.json',
#  'sample_data']

# %%
# %%capture
# !unzip "./histopathologic-cancer-detection.zip"

# %% [markdown]
# #### Commentary
#
# Now that the data are downloaded into the colab, we can go about loading them into tf.data.Dataset object. We will use the tf.keras.image_dataset_from_directory function to load in the data simply and efficiently. Unfortunately the training labels are stored in a seperate .csv file, so we will need to do some cleaning. Along with the label is a column denoting the file name of the corresponding training image. My cleaning approach was to sort the .csv by file name, pull the id's, sort the training data in an identical manner, then place all data in subdirectories corresponding to the datum label. This has the extreme benefit of allowing lazy loading for the keras.utils.image_dataset_from_directory method, built for CNN.
#
# Citation:
#
#  https://keras.io/api/data_loading/image/

# %%
#Display files in current working directory. Should include test, train, and train_labels
os.listdir("./")
# Out:
# ['.config',
#  'kaggle.json',
#  'sample_submission.csv',
#  'test',
#  'train',
#  'train_labels.csv',
#  'histopathologic-cancer-detection.zip',
#  'sample_data']

# %% [markdown]
# #### Cleaning Note:
#
# It turns out that all the image files provided in the Kaggle competition have the .tif extension, which Keras dislikes. We will need to convert these to .png in order for Keras to succeed in creating our Data object. I'll write a custom function to do this in a cell chunk below.
#
# Citation:
#
# https://www.code-learner.com/how-to-convert-image-format-using-pillow-in-python/

# %%
def convertToPNG(newDir, oldDir, fileName):
  """
  This function converts a .tif image file from oldDir to a .png and saves it to
  newDir.
  Input: string filePath
  Output: None
  """
  targetPath = newDir + fileName[:-4] + ".png"
  this_img = Image.open(oldDir + fileName)
  this_img.save(targetPath)
  this_img.close()

# %%
# Make necessary containers for converted training images
## with subdirectories for binary classification
dir0train = "./pngContainer/pngTrain/0/"
dir1train = "./pngContainer/pngTrain/1/"
os.makedirs(dir0train)
os.makedirs(dir1train)

#Read in and sort training labels alphanumerically. The sorting is identical
## to the sorting we will perform on the images (they have the same names).
train_labs_df = pd.read_csv("./train_labels.csv")
training_labels = list(train_labs_df.sort_values(by = "id", axis = 0)["label"])

# Convert all .tif files in "./train/" to .png 's . This will take about 10
## minutes total.
train_dir = "./train/"
train_imgs = os.listdir(train_dir)
train_imgs.sort()

#Quick sanity check
assert len(train_imgs) == len(training_labels)

#Populate subdirectories. This will take a while (for me ~ 10 minutes). Grab a
## snack. If there is a better way to do this I'm all ears.
for i in range(len(train_imgs)):
  if training_labels[i] == 0:
    convertToPNG(dir0train, train_dir, train_imgs[i])
  else:
    assert training_labels[i] == 1
    convertToPNG(dir1train, train_dir, train_imgs[i])

# %%
#Check that files got properly put in "./pngContainer/pngTrain" and converted to
## .png
os.remove("./histopathologic-cancer-detection.zip")
os.listdir("./pngContainer/pngTrain")
# Out:
# ['0', '1']

# %%
# Call image_dataset_from_directory to build keras Data object
train_data = tf.keras.utils.image_dataset_from_directory(
    directory = "/content/pngContainer/pngTrain",
    labels = "inferred",
    label_mode = "binary",
    color_mode = "rgb",
    image_size = (96, 96),
    seed = 42,
    batch_size = 32
)
# Out:
# Found 220025 files belonging to 2 classes.

# %%
#Confirm that training data was propertly loaded
train_data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>

# %% [markdown]
# ### Even More Exploratory Data Analysis
#
# I will first show an example photo from the training data, along with its type and shape.

# %%
# More Example Images
#Citation https://keras.io/examples/vision/image_classification_from_scratch/

plt.figure(figsize=(10, 10))
for images, labels in train_data.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
# Make Histogram of Training Labels
plt.hist(training_labels, bins = 2)
plt.xlabel("Category")
plt.ylabel("Count")
plt.title("Histogram of Training Labels")
plt.show()

# %% [markdown]
# I would like to do an EDA that consists of examining the brightness per pixel (max, min, mean) over each of the three RGB channels, but doing so would involve re-loading all of the training data using cv2, which seems like a drastic waste of memory. If you would like to see an example where I do such an EDA, please visit [my GitHub](https://github.com/EthanJTucker/DTSA_5510_HW/blob/main/Final_Project/DTSA_5510_Final_Project.ipynb).
#
# # Step 3: Model Architecture and Construction
#
# I will try a couple different architectures, because CNN architecture itself is a hyperparameter that needs optimization. Keras provides a wonderful API to build simple CNN's in. In particular, the Sequential API is built for single input single output models. We are inputting single images, and want to output a single label, so the Sequential API works perfect.
#
# We learned in class that the basic effective architecture for a CNN looks like [convolve -> convolve -> maxpool]$_n$, and then fed into a dense ANN for classification. I will use $n = 3$ for my project, because as $n$ increases the CNN develops the ability to "see" more macroscopic trends in the data, which may indicate the present of cancerous tissue. By preventing too many layers, we can try and prevent overfitting.
#
# We learned that either relu or PreLu is the best choice of activation function for hidden layers. The Keras Sequential API doesn't have a built in PreLu, and I fear that any that I implement will be algorthmically inefficient in Python, so I won't worry about optimizing the interem activation functions. We will use (3x3) filters as suggested. I will try both the Adam and RMSProp optimizers, and various values of learning rate between (0.0001, 0.001). I will also use a learning_rate scheduler to minimize variance towards the end of training. I will try Dropout layers in various locations. I will use binary cross entropy as my loss function, because it is the most appropriate for logit outputs from a sigmoid output activation.
#
# All of my hyperparameter tuning will be done manually. The fitting will take a while, but will return the optimal choice of architecture and hyperparameters by validation accuracy.
#
# Citations:
#
# https://www.tutorialspoint.com/keras/keras_convolution_neural_network.htm
#
#
# https://keras.io/guides/sequential_model/
#
# https://keras.io/api/models/model_training_apis/

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Dropout, Dense, Flatten

def buildaModel(eta, dropout1, dropout2, optimizer):
  """
  This function builds a model according to the hyperparamaters passed. The documentation for keras-tuner is quite poor, and there are many bugs.
  I will just make my own grid searcher.

  Inputs:
    float eta, learning rate
    Boolean dropout1, whether to include dropout layer after first c-c-m
    Boolean dropout2, whether to include dropout layer after second c-c-m
    string optimizer, either "Adam" or "RMSprop"

  Output: Keras sequential model object
  """
  batch_input_shape = (32, 96, 96, 3) # Mini-batches are of size 32. Images are of shape (96, 96, 3)
  model = tf.keras.Sequential()
  model.add(BatchNormalization(axis = -1))
  #CNN [c, c, m] Layers
  model.add(Conv2D(32,
                   kernel_size = 3,
                   padding="same",
                   activation = "relu",
                   batch_input_shape = batch_input_shape))
  model.add(Conv2D(32, kernel_size = 3, activation = "relu"))
  model.add(MaxPooling2D(pool_size = 2))
  model.add(BatchNormalization(axis = -1)) #Normalize to prevent overfitting

  model.add(Conv2D(64, kernel_size = 3, activation = "relu"))
  model.add(Conv2D(64, kernel_size = 3, activation = "relu"))
  model.add(MaxPooling2D(pool_size = 2))
  #Decide whether or not to use a Dropout between [c, c, m] instances
  model.add(BatchNormalization(axis = -1)) #Normalize to prevent overfitting

  model.add(Conv2D(128, kernel_size = 3, activation = "relu"))
  model.add(Conv2D(128, kernel_size = 3, activation = "relu"))
  model.add(MaxPooling2D(pool_size = 2))
  #Decide whether or not to use a Dropout between [c, c, m] instances
  model.add(BatchNormalization(axis = -1)) #Normalize to prevent overfitting

  #Now send the model into an ANN for binary classification
  model.add(Flatten())
  if dropout1:
    model.add(Dropout(0.25))
  model.add(Dense(256, activation = "relu"))
  model.add(Dense(128, activation = "relu"))
  if dropout2:
    model.add(Dropout(0.25))
  model.add(Dense(32, activation = "relu"))
  model.add(Dense(1, activation = "sigmoid")) #Output layer

  #Make a learning rate schedule to prevent variance at the end of training
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
      initial_learning_rate = eta,
      decay_steps = 10000,
      decay_rate=0.9
      )

  #Compile the model
  if optimizer == "Adam":
    model.compile(
      optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule),
      loss = "binary_crossentropy",
      metrics=["accuracy"]
    )
  else:
    assert optimizer == "RMSprop"
    model.compile(
      optimizer = tf.keras.optimizers.RMSprop(learning_rate = lr_schedule),
      loss = "binary_crossentropy",
      metrics = ["accuracy"]
    )
  return(model)

# %%
#Trial model before gridsearch
myModel = buildaModel(eta = 0.001, dropout1 = True, dropout2 = True, optimizer = "Adam")
callbacks_list =  [tf.keras.callbacks.EarlyStopping(monitor="loss", patience = 10, mode = "min")]
history = myModel.fit(train_data,
                      epochs = 99,
                      steps_per_epoch = len(train_data)/100,
                      callbacks = callbacks_list)

print(myModel.summary())
# Out:
# Epoch 1/99
# 68/68 [==============================] - 19s 61ms/step - loss: 0.6519 - accuracy: 0.7047
# Epoch 2/99
# 68/68 [==============================] - 4s 61ms/step - loss: 0.5592 - accuracy: 0.7591
# Epoch 3/99
# 68/68 [==============================] - 4s 61ms/step - loss: 0.4936 - accuracy: 0.7754
# Epoch 4/99
# 68/68 [==============================] - 4s 61ms/step - loss: 0.4767 - accuracy: 0.7853
# Epoch 5/99
# 68/68 [==============================] - 4s 61ms/step - loss: 0.4668 - accuracy: 0.7962
# Epoch 6/99
# 68/68 [==============================] - 4s 58ms/step - loss: 0.4586 - accuracy: 0.8007
# Epoch 7/99
# 68/68 [==============================] - 4s 60ms/step - loss: 0.4594 - accuracy: 0.8034
# Epoch 8/99
# 68/68 [==============================] - 4s 62ms/step - loss: 0.4389 - accuracy: 0.8120
# Epoch 9/99
# 68/68 [==============================] - 4s 60ms/step - loss: 0.4213 - accuracy: 0.8116
# Epoch 10/99
# 68/68 [==============================] - 4s 58ms/step - loss: 0.4122 - accuracy: 0.8225
# Epoch 11/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.3985 - accuracy: 0.8284
# Epoch 12/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.3896 - accuracy: 0.8397
# Epoch 13/99
# 68/68 [==============================] - 4s 58ms/step - loss: 0.4104 - accuracy: 0.8265
# Epoch 14/99
# 68/68 [==============================] - 4s 58ms/step - loss: 0.3806 - accuracy: 0.8338
# Epoch 15/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.3864 - accuracy: 0.8284
# Epoch 16/99
# 68/68 [==============================] - 4s 55ms/step - loss: 0.3777 - accuracy: 0.8356
# Epoch 17/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.3922 - accuracy: 0.8338
# Epoch 18/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.3848 - accuracy: 0.8297
# Epoch 19/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.4202 - accuracy: 0.8139
# Epoch 20/99
# 68/68 [==============================] - 4s 55ms/step - loss: 0.4034 - accuracy: 0.8284
# Epoch 21/99
# 68/68 [==============================] - 4s 55ms/step - loss: 0.3795 - accuracy: 0.8438
# Epoch 22/99
# 68/68 [==============================] - 4s 55ms/step - loss: 0.3681 - accuracy: 0.8505
# Epoch 23/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.3787 - accuracy: 0.8410
# Epoch 24/99
# 68/68 [==============================] - 5s 66ms/step - loss: 0.3369 - accuracy: 0.8628
# Epoch 25/99
# 68/68 [==============================] - 4s 53ms/step - loss: 0.3455 - accuracy: 0.8591
# Epoch 26/99
# 68/68 [==============================] - 4s 53ms/step - loss: 0.3782 - accuracy: 0.8469
# Epoch 27/99
# 68/68 [==============================] - 4s 55ms/step - loss: 0.3641 - accuracy: 0.8546
# Epoch 28/99
# 68/68 [==============================] - 4s 52ms/step - loss: 0.3617 - accuracy: 0.8451
# Epoch 29/99
# 68/68 [==============================] - 3s 50ms/step - loss: 0.3523 - accuracy: 0.8582
# Epoch 30/99
# 68/68 [==============================] - 4s 53ms/step - loss: 0.3649 - accuracy: 0.8465
# Epoch 31/99
# 68/68 [==============================] - 3s 49ms/step - loss: 0.3339 - accuracy: 0.8655
# Epoch 32/99
# 68/68 [==============================] - 3s 49ms/step - loss: 0.3517 - accuracy: 0.8564
# Epoch 33/99
# 68/68 [==============================] - 3s 50ms/step - loss: 0.3201 - accuracy: 0.8696
# Epoch 34/99
# 68/68 [==============================] - 3s 50ms/step - loss: 0.3415 - accuracy: 0.8505
# Epoch 35/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3274 - accuracy: 0.8668
# Epoch 36/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3224 - accuracy: 0.8646
# Epoch 37/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3240 - accuracy: 0.8700
# Epoch 38/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3170 - accuracy: 0.8705
# Epoch 39/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3111 - accuracy: 0.8809
# Epoch 40/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3149 - accuracy: 0.8714
# Epoch 41/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3155 - accuracy: 0.8696
# Epoch 42/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3096 - accuracy: 0.8813
# Epoch 43/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3152 - accuracy: 0.8709
# Epoch 44/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3311 - accuracy: 0.8646
# Epoch 45/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3202 - accuracy: 0.8655
# Epoch 46/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3206 - accuracy: 0.8687
# Epoch 47/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3122 - accuracy: 0.8714
# Epoch 48/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3157 - accuracy: 0.8723
# Epoch 49/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.2802 - accuracy: 0.8899
# Epoch 50/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.2560 - accuracy: 0.8990
# Epoch 51/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.2887 - accuracy: 0.8877
# Epoch 52/99
# 68/68 [==============================] - 3s 48ms/step - loss: 0.3083 - accuracy: 0.8696
# Epoch 53/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.3101 - accuracy: 0.8668
# Epoch 54/99
# 68/68 [==============================] - 4s 53ms/step - loss: 0.3093 - accuracy: 0.8782
# Epoch 55/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3025 - accuracy: 0.8718
# Epoch 56/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3081 - accuracy: 0.8682
# Epoch 57/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.2846 - accuracy: 0.8777
# Epoch 58/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3010 - accuracy: 0.8777
# Epoch 59/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.2858 - accuracy: 0.8822
# Epoch 60/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3029 - accuracy: 0.8818
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 96, 96, 3)        12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 96, 96, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 94, 94, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 47, 47, 32)       0
#  )
#
#  batch_normalization_1 (Batc  (None, 47, 47, 32)       128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 43, 43, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 21, 64)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 21, 21, 64)       256
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 19, 19, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 17, 17, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout (Dropout)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,422,381
# Trainable params: 2,421,927
# Non-trainable params: 454
# _________________________________________________________________
# None

# %%
# Make a nice visualization of our test model: Training Accuracy Vs. Epoch
testAccs = history.history["accuracy"]
epochs = [i for i in range(len(testAccs))]
plt.plot(epochs, testAccs)
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.title("Training Accuracy Vs. Epoch")
plt.show()

# %%
# Make another nice visualization: Loss Vs. Epoch
testLosses = history.history["loss"]
plt.plot(epochs, testLosses)
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.title("Training Loss Vs. Epoch")
plt.show()

# %% [markdown]
# ### Success!
#
# Now that we have confirmed that the model construction function works, we can go about doing our HP optimization. To reiterate, we will choose various initial learning rates and dropout layer inclusions to differentiate our models. The values of $\eta$ that I will initially scan are $\{0.0001, 0.0005, 0.001, 0.005, 0.01\}$. After running these models, I will try some ad hoc values to get try and get the validation accuracy up a bit more. After this I will experiment with dropout layers. I want at least one dropout layers, so I will try permutations with at least one 'True' values. Finally, we will also try changing the optimizer.
#
# This next cell execution will take a while - go grab a snack (or just don't execute it because it is pre-populated in the .ipynb). The total training time for the test model was ~ 3.5 minutes, so over 30 options we would expect 105 minutes of training.

# %%
#Perform HP optimization
import itertools
startTime = time.time()
callbacks_list =  [tf.keras.callbacks.EarlyStopping(monitor="loss", patience = 10, mode = "min")]
eta_to_try = [0.0001, 0.001, 0.005, 0.01]
dropouts_to_try = [(True, True)]
optimizers_to_try = ["Adam", "RMSprop"]

hpPermutations = list(itertools.product(*[eta_to_try, dropouts_to_try, optimizers_to_try]))
current_best_model = (None, 0)
current_best_history = None

model_accuracies = list()
for hpList in hpPermutations:
  print("Now trying hyperparams:", hpList)
  this_model = buildaModel(eta = hpList[0],
                           dropout1 = True,
                           dropout2 = True,
                           optimizer = hpList[2]
                           )
  this_history = this_model.fit(train_data,
                                epochs = 99,
                                steps_per_epoch = len(train_data)/100,
                                callbacks = callbacks_list
                                )
  if this_history.history["accuracy"][-1] > current_best_model[1]:
    current_best_model = (this_model, this_history.history["accuracy"][-1])
    current_best_history = this_history.history

endTime = time.time()
print("Total HP optimization time:", round((endTime - startTime)/60, 3), "minutes")
# Out:
# Now trying hyperparams: (0.001, (True, True), 'Adam')
# Epoch 1/99
# 68/68 [==============================] - 18s 61ms/step - loss: 0.6703 - accuracy: 0.7052
# Epoch 2/99
# 68/68 [==============================] - 5s 67ms/step - loss: 0.5611 - accuracy: 0.7604
# Epoch 3/99
# 68/68 [==============================] - 4s 62ms/step - loss: 0.5039 - accuracy: 0.7853
# Epoch 4/99
# 68/68 [==============================] - 4s 60ms/step - loss: 0.4740 - accuracy: 0.7917
# Epoch 5/99
# 68/68 [==============================] - 4s 61ms/step - loss: 0.4533 - accuracy: 0.8075
# Epoch 6/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.4419 - accuracy: 0.8107
# Epoch 7/99
# 68/68 [==============================] - 4s 59ms/step - loss: 0.4488 - accuracy: 0.7994
# Epoch 8/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.4191 - accuracy: 0.8184
# Epoch 9/99
# 68/68 [==============================] - 4s 58ms/step - loss: 0.4129 - accuracy: 0.8179
# Epoch 10/99
# 68/68 [==============================] - 4s 58ms/step - loss: 0.4134 - accuracy: 0.8356
# Epoch 11/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.3851 - accuracy: 0.8456
# Epoch 12/99
# 68/68 [==============================] - 4s 55ms/step - loss: 0.3914 - accuracy: 0.8365
# Epoch 13/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.4005 - accuracy: 0.8193
# Epoch 14/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.3724 - accuracy: 0.8392
# Epoch 15/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.3748 - accuracy: 0.8406
# Epoch 16/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.3681 - accuracy: 0.8392
# Epoch 17/99
# 68/68 [==============================] - 4s 54ms/step - loss: 0.3916 - accuracy: 0.8315
# Epoch 18/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.3717 - accuracy: 0.8365
# Epoch 19/99
# 68/68 [==============================] - 4s 54ms/step - loss: 0.4122 - accuracy: 0.8179
# Epoch 20/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.4046 - accuracy: 0.8247
# Epoch 21/99
# 68/68 [==============================] - 4s 53ms/step - loss: 0.3768 - accuracy: 0.8460
# Epoch 22/99
# 68/68 [==============================] - 4s 54ms/step - loss: 0.3645 - accuracy: 0.8442
# Epoch 23/99
# 68/68 [==============================] - 4s 54ms/step - loss: 0.3826 - accuracy: 0.8370
# Epoch 24/99
# 68/68 [==============================] - 4s 52ms/step - loss: 0.3343 - accuracy: 0.8673
# Epoch 25/99
# 68/68 [==============================] - 3s 50ms/step - loss: 0.3413 - accuracy: 0.8610
# Epoch 26/99
# 68/68 [==============================] - 4s 53ms/step - loss: 0.3671 - accuracy: 0.8460
# Epoch 27/99
# 68/68 [==============================] - 3s 50ms/step - loss: 0.3661 - accuracy: 0.8501
# Epoch 28/99
# 68/68 [==============================] - 4s 61ms/step - loss: 0.3514 - accuracy: 0.8524
# Epoch 29/99
# 68/68 [==============================] - 4s 51ms/step - loss: 0.3571 - accuracy: 0.8514
# Epoch 30/99
# 68/68 [==============================] - 3s 48ms/step - loss: 0.3563 - accuracy: 0.8442
# Epoch 31/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3435 - accuracy: 0.8601
# Epoch 32/99
# 68/68 [==============================] - 3s 50ms/step - loss: 0.3506 - accuracy: 0.8569
# Epoch 33/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3138 - accuracy: 0.8714
# Epoch 34/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3380 - accuracy: 0.8573
# Epoch 35/99
# 68/68 [==============================] - 3s 48ms/step - loss: 0.3284 - accuracy: 0.8646
# Epoch 36/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3164 - accuracy: 0.8768
# Epoch 37/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3277 - accuracy: 0.8714
# Epoch 38/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3029 - accuracy: 0.8736
# Epoch 39/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3169 - accuracy: 0.8668
# Epoch 40/99
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2995 - accuracy: 0.8773
# Epoch 41/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3015 - accuracy: 0.8709
# Epoch 42/99
# 68/68 [==============================] - 3s 42ms/step - loss: 0.3195 - accuracy: 0.8741
# Epoch 43/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3105 - accuracy: 0.8691
# Epoch 44/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3297 - accuracy: 0.8705
# Epoch 45/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3159 - accuracy: 0.8691
# Epoch 46/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3196 - accuracy: 0.8678
# Epoch 47/99
# 68/68 [==============================] - 3s 42ms/step - loss: 0.3035 - accuracy: 0.8768
# Epoch 48/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3122 - accuracy: 0.8800
# Epoch 49/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.2707 - accuracy: 0.8963
# Epoch 50/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2585 - accuracy: 0.8922
# Epoch 51/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.2895 - accuracy: 0.8872
# Epoch 52/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3087 - accuracy: 0.8678
# Epoch 53/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3003 - accuracy: 0.8777
# Epoch 54/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2871 - accuracy: 0.8868
# Epoch 55/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.2992 - accuracy: 0.8782
# Epoch 56/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.2993 - accuracy: 0.8745
# Epoch 57/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.2977 - accuracy: 0.8687
# Epoch 58/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2966 - accuracy: 0.8764
# Epoch 59/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.2830 - accuracy: 0.8872
# Epoch 60/99
# 68/68 [==============================] - 4s 54ms/step - loss: 0.2976 - accuracy: 0.8755
# Now trying hyperparams: (0.001, (True, True), 'RMSprop')
# Epoch 1/99
# 68/68 [==============================] - 6s 47ms/step - loss: 0.9020 - accuracy: 0.7024
# Epoch 2/99
# 68/68 [==============================] - 3s 49ms/step - loss: 0.5930 - accuracy: 0.7414
# Epoch 3/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.5231 - accuracy: 0.7880
# Epoch 4/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.4651 - accuracy: 0.8048
# Epoch 5/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.4785 - accuracy: 0.7953
# Epoch 6/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4556 - accuracy: 0.8157
# Epoch 7/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.4460 - accuracy: 0.8161
# Epoch 8/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4312 - accuracy: 0.8179
# Epoch 9/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4379 - accuracy: 0.8152
# Epoch 10/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.4414 - accuracy: 0.8265
# Epoch 11/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3951 - accuracy: 0.8406
# Epoch 12/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4165 - accuracy: 0.8252
# Epoch 13/99
# 68/68 [==============================] - 3s 48ms/step - loss: 0.4274 - accuracy: 0.8256
# Epoch 14/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3872 - accuracy: 0.8433
# Epoch 15/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4053 - accuracy: 0.8315
# Epoch 16/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3889 - accuracy: 0.8401
# Epoch 17/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3922 - accuracy: 0.8397
# Epoch 18/99
# 68/68 [==============================] - 3s 49ms/step - loss: 0.4285 - accuracy: 0.8252
# Epoch 19/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4233 - accuracy: 0.8193
# Epoch 20/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4200 - accuracy: 0.8175
# Epoch 21/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3936 - accuracy: 0.8356
# Epoch 22/99
# 68/68 [==============================] - 3s 48ms/step - loss: 0.3860 - accuracy: 0.8419
# Epoch 23/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4044 - accuracy: 0.8433
# Epoch 24/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3942 - accuracy: 0.8406
# Epoch 25/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3606 - accuracy: 0.8483
# Epoch 26/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3765 - accuracy: 0.8519
# Epoch 27/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3881 - accuracy: 0.8474
# Epoch 28/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3877 - accuracy: 0.8492
# Epoch 29/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3947 - accuracy: 0.8478
# Epoch 30/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3999 - accuracy: 0.8424
# Epoch 31/99
# 68/68 [==============================] - 4s 59ms/step - loss: 0.3866 - accuracy: 0.8546
# Epoch 32/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3802 - accuracy: 0.8591
# Epoch 33/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3540 - accuracy: 0.8637
# Epoch 34/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3770 - accuracy: 0.8524
# Epoch 35/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3823 - accuracy: 0.8524
# Epoch 36/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3814 - accuracy: 0.8492
# Epoch 37/99
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3642 - accuracy: 0.8442
# Epoch 38/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3918 - accuracy: 0.8614
# Epoch 39/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3647 - accuracy: 0.8664
# Epoch 40/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3484 - accuracy: 0.8623
# Epoch 41/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3582 - accuracy: 0.8614
# Epoch 42/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3822 - accuracy: 0.8496
# Epoch 43/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3761 - accuracy: 0.8560
# Epoch 44/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3693 - accuracy: 0.8438
# Epoch 45/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3649 - accuracy: 0.8460
# Epoch 46/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.4145 - accuracy: 0.8524
# Epoch 47/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.4884 - accuracy: 0.8510
# Epoch 48/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3622 - accuracy: 0.8596
# Epoch 49/99
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3218 - accuracy: 0.8782
# Epoch 50/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3229 - accuracy: 0.8682
# Epoch 51/99
# 68/68 [==============================] - 2s 35ms/step - loss: 0.3568 - accuracy: 0.8723
# Epoch 52/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3753 - accuracy: 0.8510
# Epoch 53/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3784 - accuracy: 0.8474
# Epoch 54/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3355 - accuracy: 0.8605
# Epoch 55/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3868 - accuracy: 0.8492
# Epoch 56/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3412 - accuracy: 0.8705
# Epoch 57/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3721 - accuracy: 0.8664
# Epoch 58/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3626 - accuracy: 0.8605
# Epoch 59/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3495 - accuracy: 0.8650
# Now trying hyperparams: (0.005, (True, True), 'Adam')
# Epoch 1/99
# 68/68 [==============================] - 4s 30ms/step - loss: 0.8263 - accuracy: 0.6984
# Epoch 2/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5245 - accuracy: 0.7704
# Epoch 3/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5066 - accuracy: 0.7785
# Epoch 4/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4635 - accuracy: 0.7948
# Epoch 5/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4440 - accuracy: 0.8053
# Epoch 6/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4325 - accuracy: 0.8193
# Epoch 7/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4297 - accuracy: 0.8148
# Epoch 8/99
# 68/68 [==============================] - 2s 29ms/step - loss: 0.4269 - accuracy: 0.8130
# Epoch 9/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4458 - accuracy: 0.8098
# Epoch 10/99
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4208 - accuracy: 0.8175
# Epoch 11/99
# 68/68 [==============================] - 3s 42ms/step - loss: 0.4080 - accuracy: 0.8338
# Epoch 12/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4142 - accuracy: 0.8166
# Epoch 13/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4063 - accuracy: 0.8229
# Epoch 14/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3854 - accuracy: 0.8401
# Epoch 15/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4263 - accuracy: 0.8148
# Epoch 16/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3910 - accuracy: 0.8315
# Epoch 17/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4194 - accuracy: 0.8252
# Epoch 18/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4079 - accuracy: 0.8193
# Epoch 19/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4405 - accuracy: 0.8107
# Epoch 20/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4183 - accuracy: 0.8256
# Epoch 21/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4061 - accuracy: 0.8238
# Epoch 22/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3878 - accuracy: 0.8514
# Epoch 23/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3966 - accuracy: 0.8324
# Epoch 24/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3750 - accuracy: 0.8492
# Epoch 25/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3915 - accuracy: 0.8401
# Epoch 26/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4103 - accuracy: 0.8274
# Epoch 27/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3991 - accuracy: 0.8374
# Epoch 28/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3941 - accuracy: 0.8392
# Epoch 29/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3821 - accuracy: 0.8401
# Epoch 30/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3872 - accuracy: 0.8315
# Epoch 31/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3553 - accuracy: 0.8487
# Epoch 32/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3624 - accuracy: 0.8424
# Epoch 33/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3808 - accuracy: 0.8474
# Epoch 34/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3950 - accuracy: 0.8356
# Epoch 35/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3837 - accuracy: 0.8365
# Epoch 36/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3682 - accuracy: 0.8492
# Epoch 37/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3846 - accuracy: 0.8379
# Epoch 38/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3583 - accuracy: 0.8478
# Epoch 39/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3820 - accuracy: 0.8392
# Epoch 40/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3584 - accuracy: 0.8460
# Epoch 41/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3723 - accuracy: 0.8383
# Now trying hyperparams: (0.005, (True, True), 'RMSprop')
# Epoch 1/99
# 68/68 [==============================] - 4s 31ms/step - loss: 1.6746 - accuracy: 0.6553
# Epoch 2/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.8678 - accuracy: 0.6173
# Epoch 3/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.6878 - accuracy: 0.6187
# Epoch 4/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5985 - accuracy: 0.7505
# Epoch 5/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5598 - accuracy: 0.7486
# Epoch 6/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5829 - accuracy: 0.7586
# Epoch 7/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5447 - accuracy: 0.7572
# Epoch 8/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5233 - accuracy: 0.7817
# Epoch 9/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5023 - accuracy: 0.7876
# Epoch 10/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5019 - accuracy: 0.8143
# Epoch 11/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4811 - accuracy: 0.8084
# Epoch 12/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5065 - accuracy: 0.8025
# Epoch 13/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4731 - accuracy: 0.7948
# Epoch 14/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4472 - accuracy: 0.8148
# Epoch 15/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4566 - accuracy: 0.8179
# Epoch 16/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4420 - accuracy: 0.8179
# Epoch 17/99
# 68/68 [==============================] - 3s 45ms/step - loss: 0.4539 - accuracy: 0.8139
# Epoch 18/99
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4376 - accuracy: 0.8279
# Epoch 19/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4485 - accuracy: 0.8093
# Epoch 20/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4387 - accuracy: 0.8170
# Epoch 21/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4405 - accuracy: 0.8207
# Epoch 22/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4498 - accuracy: 0.8184
# Epoch 23/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4292 - accuracy: 0.8184
# Epoch 24/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4389 - accuracy: 0.8284
# Epoch 25/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4106 - accuracy: 0.8415
# Epoch 26/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4307 - accuracy: 0.8361
# Epoch 27/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4297 - accuracy: 0.8329
# Epoch 28/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4439 - accuracy: 0.8102
# Epoch 29/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4341 - accuracy: 0.8329
# Epoch 30/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4408 - accuracy: 0.8193
# Epoch 31/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4195 - accuracy: 0.8311
# Epoch 32/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4234 - accuracy: 0.8361
# Epoch 33/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4043 - accuracy: 0.8447
# Epoch 34/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4260 - accuracy: 0.8270
# Epoch 35/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4342 - accuracy: 0.8125
# Epoch 36/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4220 - accuracy: 0.8419
# Epoch 37/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3993 - accuracy: 0.8392
# Epoch 38/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3899 - accuracy: 0.8428
# Epoch 39/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3814 - accuracy: 0.8433
# Epoch 40/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3895 - accuracy: 0.8591
# Epoch 41/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4220 - accuracy: 0.8320
# Epoch 42/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3786 - accuracy: 0.8465
# Epoch 43/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3965 - accuracy: 0.8392
# Epoch 44/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4269 - accuracy: 0.8329
# Epoch 45/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4199 - accuracy: 0.8347
# Epoch 46/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4210 - accuracy: 0.8379
# Epoch 47/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3748 - accuracy: 0.8465
# Epoch 48/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3989 - accuracy: 0.8365
# Epoch 49/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3728 - accuracy: 0.8668
# Epoch 50/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3711 - accuracy: 0.8528
# Epoch 51/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3821 - accuracy: 0.8401
# Epoch 52/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3748 - accuracy: 0.8406
# Epoch 53/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4149 - accuracy: 0.8324
# Epoch 54/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3922 - accuracy: 0.8361
# Epoch 55/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4006 - accuracy: 0.8410
# Epoch 56/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3973 - accuracy: 0.8510
# Epoch 57/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4271 - accuracy: 0.8234
# Epoch 58/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3973 - accuracy: 0.8524
# Epoch 59/99
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4066 - accuracy: 0.8401
# Epoch 60/99
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4001 - accuracy: 0.8492
# Now trying hyperparams: (0.01, (True, True), 'Adam')
# Epoch 1/99
# 68/68 [==============================] - 3s 31ms/step - loss: 1.7592 - accuracy: 0.6381
# Epoch 2/99
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6276 - accuracy: 0.7038
# Epoch 3/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5624 - accuracy: 0.7486
# Epoch 4/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5662 - accuracy: 0.7677
# Epoch 5/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4994 - accuracy: 0.7826
# Epoch 6/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4656 - accuracy: 0.7903
# Epoch 7/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4611 - accuracy: 0.8125
# Epoch 8/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4620 - accuracy: 0.8003
# Epoch 9/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5490 - accuracy: 0.7754
# Epoch 10/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4777 - accuracy: 0.8016
# Epoch 11/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4752 - accuracy: 0.8193
# Epoch 12/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4952 - accuracy: 0.8093
# Epoch 13/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5161 - accuracy: 0.7731
# Epoch 14/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4644 - accuracy: 0.8139
# Epoch 15/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4316 - accuracy: 0.8234
# Epoch 16/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4406 - accuracy: 0.8175
# Epoch 17/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5107 - accuracy: 0.7935
# Epoch 18/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4790 - accuracy: 0.7980
# Epoch 19/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4609 - accuracy: 0.7966
# Epoch 20/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4810 - accuracy: 0.7953
# Epoch 21/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4707 - accuracy: 0.8034
# Epoch 22/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4651 - accuracy: 0.8043
# Epoch 23/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4299 - accuracy: 0.8193
# Epoch 24/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4315 - accuracy: 0.8211
# Epoch 25/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4347 - accuracy: 0.8148
# Epoch 26/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4308 - accuracy: 0.8134
# Epoch 27/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4356 - accuracy: 0.8157
# Epoch 28/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4246 - accuracy: 0.8152
# Epoch 29/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4273 - accuracy: 0.8152
# Epoch 30/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4385 - accuracy: 0.8211
# Epoch 31/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4202 - accuracy: 0.8284
# Epoch 32/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.3994 - accuracy: 0.8302
# Epoch 33/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4110 - accuracy: 0.8279
# Epoch 34/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4542 - accuracy: 0.8098
# Epoch 35/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4165 - accuracy: 0.8306
# Epoch 36/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4195 - accuracy: 0.8238
# Epoch 37/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4434 - accuracy: 0.8238
# Epoch 38/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4338 - accuracy: 0.8238
# Epoch 39/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4445 - accuracy: 0.8125
# Epoch 40/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4330 - accuracy: 0.8107
# Epoch 41/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4293 - accuracy: 0.8179
# Epoch 42/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4557 - accuracy: 0.8193
# Now trying hyperparams: (0.01, (True, True), 'RMSprop')
# Epoch 1/99
# 68/68 [==============================] - 4s 32ms/step - loss: 4.8371 - accuracy: 0.6553
# Epoch 2/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.8274 - accuracy: 0.6409
# Epoch 3/99
# 68/68 [==============================] - 2s 34ms/step - loss: 0.7204 - accuracy: 0.6024
# Epoch 4/99
# 68/68 [==============================] - 3s 44ms/step - loss: 0.6967 - accuracy: 0.5942
# Epoch 5/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.6897 - accuracy: 0.5838
# Epoch 6/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5938 - accuracy: 0.7015
# Epoch 7/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5909 - accuracy: 0.7563
# Epoch 8/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5535 - accuracy: 0.7468
# Epoch 9/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5300 - accuracy: 0.7763
# Epoch 10/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5009 - accuracy: 0.7908
# Epoch 11/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4720 - accuracy: 0.7998
# Epoch 12/99
# 68/68 [==============================] - 2s 30ms/step - loss: 0.5053 - accuracy: 0.7962
# Epoch 13/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4697 - accuracy: 0.8125
# Epoch 14/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4505 - accuracy: 0.8157
# Epoch 15/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4623 - accuracy: 0.8053
# Epoch 16/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4369 - accuracy: 0.8261
# Epoch 17/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4692 - accuracy: 0.8152
# Epoch 18/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4748 - accuracy: 0.8152
# Epoch 19/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4783 - accuracy: 0.8066
# Epoch 20/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4592 - accuracy: 0.8084
# Epoch 21/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4690 - accuracy: 0.8170
# Epoch 22/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4666 - accuracy: 0.8030
# Epoch 23/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4529 - accuracy: 0.8193
# Epoch 24/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4352 - accuracy: 0.8229
# Epoch 25/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4280 - accuracy: 0.8361
# Epoch 26/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4629 - accuracy: 0.8225
# Epoch 27/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4360 - accuracy: 0.8193
# Epoch 28/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4675 - accuracy: 0.8225
# Epoch 29/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4459 - accuracy: 0.8166
# Epoch 30/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4422 - accuracy: 0.8202
# Epoch 31/99
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4463 - accuracy: 0.8284
# Epoch 32/99
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4365 - accuracy: 0.8243
# Epoch 33/99
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4467 - accuracy: 0.8370
# Epoch 34/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4473 - accuracy: 0.8315
# Epoch 35/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4203 - accuracy: 0.8265
# Epoch 36/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4210 - accuracy: 0.8297
# Epoch 37/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4564 - accuracy: 0.8102
# Epoch 38/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4128 - accuracy: 0.8238
# Epoch 39/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4503 - accuracy: 0.8279
# Epoch 40/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3966 - accuracy: 0.8447
# Epoch 41/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4274 - accuracy: 0.8270
# Epoch 42/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4925 - accuracy: 0.8107
# Epoch 43/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4348 - accuracy: 0.8293
# Epoch 44/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4493 - accuracy: 0.8166
# Epoch 45/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4332 - accuracy: 0.8216
# Epoch 46/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4315 - accuracy: 0.8247
# Epoch 47/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4095 - accuracy: 0.8225
# Epoch 48/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4238 - accuracy: 0.8388
# Epoch 49/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.3754 - accuracy: 0.8456
# Epoch 50/99
# 68/68 [==============================] - 3s 38ms/step - loss: 0.4001 - accuracy: 0.8410
# Epoch 51/99
# 68/68 [==============================] - 3s 41ms/step - loss: 0.3989 - accuracy: 0.8428
# Epoch 52/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4304 - accuracy: 0.8415
# Epoch 53/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4333 - accuracy: 0.8297
# Epoch 54/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4316 - accuracy: 0.8279
# Epoch 55/99
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4104 - accuracy: 0.8320
# Epoch 56/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4037 - accuracy: 0.8397
# Epoch 57/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4218 - accuracy: 0.8306
# Epoch 58/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4258 - accuracy: 0.8311
# Epoch 59/99
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4356 - accuracy: 0.8229
# Total HP optimization time: 14.205 minutes

# %%
# Try best settings with a smaller value for eta and compare
mod = buildaModel(0.0001, True, True, "Adam")
mod.fit(train_data,
        epochs = 99,
        steps_per_epoch = len(train_data)/100,
        callbacks = callbacks_list)
# Out:
# Epoch 1/99
# 68/68 [==============================] - 7s 67ms/step - loss: 0.5496 - accuracy: 0.7292
# Epoch 2/99
# 68/68 [==============================] - 4s 62ms/step - loss: 0.5211 - accuracy: 0.7668
# Epoch 3/99
# 68/68 [==============================] - 4s 62ms/step - loss: 0.4978 - accuracy: 0.7677
# Epoch 4/99
# 68/68 [==============================] - 4s 63ms/step - loss: 0.4846 - accuracy: 0.7808
# Epoch 5/99
# 68/68 [==============================] - 5s 68ms/step - loss: 0.4804 - accuracy: 0.7862
# Epoch 6/99
# 68/68 [==============================] - 4s 60ms/step - loss: 0.4769 - accuracy: 0.7758
# Epoch 7/99
# 68/68 [==============================] - 4s 62ms/step - loss: 0.4722 - accuracy: 0.7871
# Epoch 8/99
# 68/68 [==============================] - 4s 62ms/step - loss: 0.4623 - accuracy: 0.7894
# Epoch 9/99
# 68/68 [==============================] - 4s 59ms/step - loss: 0.4470 - accuracy: 0.8003
# Epoch 10/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.4559 - accuracy: 0.8048
# Epoch 11/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.4391 - accuracy: 0.8102
# Epoch 12/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.4493 - accuracy: 0.7976
# Epoch 13/99
# 68/68 [==============================] - 4s 56ms/step - loss: 0.4365 - accuracy: 0.8043
# Epoch 14/99
# 68/68 [==============================] - 4s 57ms/step - loss: 0.4051 - accuracy: 0.8148
# Epoch 15/99
# 68/68 [==============================] - 4s 55ms/step - loss: 0.4272 - accuracy: 0.8161
# Epoch 16/99
# 68/68 [==============================] - 4s 58ms/step - loss: 0.4214 - accuracy: 0.8116
# Epoch 17/99
# 68/68 [==============================] - 4s 60ms/step - loss: 0.4139 - accuracy: 0.8152
# Epoch 18/99
# 68/68 [==============================] - 4s 53ms/step - loss: 0.4366 - accuracy: 0.8134
# Epoch 19/99
# 68/68 [==============================] - 4s 52ms/step - loss: 0.4428 - accuracy: 0.8066
# Epoch 20/99
# 68/68 [==============================] - 4s 53ms/step - loss: 0.4157 - accuracy: 0.8166
# Epoch 21/99
# 68/68 [==============================] - 4s 52ms/step - loss: 0.4119 - accuracy: 0.8152
# Epoch 22/99
# 68/68 [==============================] - 4s 52ms/step - loss: 0.3950 - accuracy: 0.8256
# Epoch 23/99
# 68/68 [==============================] - 4s 51ms/step - loss: 0.4081 - accuracy: 0.8130
# Epoch 24/99
# 68/68 [==============================] - 3s 50ms/step - loss: 0.4012 - accuracy: 0.8279
# Epoch 25/99
# 68/68 [==============================] - 4s 54ms/step - loss: 0.4068 - accuracy: 0.8370
# Epoch 26/99
# 68/68 [==============================] - 4s 53ms/step - loss: 0.4001 - accuracy: 0.8243
# Epoch 27/99
# 68/68 [==============================] - 3s 48ms/step - loss: 0.3800 - accuracy: 0.8406
# Epoch 28/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4135 - accuracy: 0.8161
# Epoch 29/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4172 - accuracy: 0.8202
# Epoch 30/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4303 - accuracy: 0.8012
# Epoch 31/99
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3886 - accuracy: 0.8247
# Epoch 32/99
# 68/68 [==============================] - 5s 76ms/step - loss: 0.3893 - accuracy: 0.8274
# Epoch 33/99
# 68/68 [==============================] - 4s 59ms/step - loss: 0.3813 - accuracy: 0.8324
# Epoch 34/99
# 68/68 [==============================] - 4s 58ms/step - loss: 0.3921 - accuracy: 0.8265
# Epoch 35/99
# 68/68 [==============================] - 4s 52ms/step - loss: 0.3808 - accuracy: 0.8361
# Epoch 36/99
# 68/68 [==============================] - 3s 51ms/step - loss: 0.3849 - accuracy: 0.8447
# Epoch 37/99
# 68/68 [==============================] - 4s 58ms/step - loss: 0.3831 - accuracy: 0.8401

# %% [markdown]
# ## Results and Analysis
#
# The model is trained! We performed a grid search over a few hyperparameters, namely various selections of learning rate chosen logarithmically on the set [0.0001, 0.01], and where to use dropout layers.
#
# The metric we optimized against was validation accuracy. I expect the test data to have accuracy approximately equal to the best validation accuracy, because we didn't train the CNN on either set. I'll make visualizations of validation_accuracy vs. epoch, and training loss vs. epoch. I think some great visualizations I'll do for my final will be validation accuracy vs. $\eta$, and execution time vs. validation accuracy. Unfortunately for this project I couldn't get the model.fit() method to accept validation_data, but I found a nice tutorial online where I think I can replicate the results. That's for another day.
#
# After these visualizations I will create label predictions for the test set, then send them to Kaggle for the test accuracy.
#
# I have included the configuration of the best model after HP optimization.

# %%
print(current_best_model[0].optimizer)
dir(current_best_model[0])
# Out:
# <keras.optimizer_v2.adam.Adam object at 0x7f5578ab1cd0>
# ['_SCALAR_UPRANKING_ON',
#  '_TF_MODULE_IGNORED_PROPERTIES',
#  '__call__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activity_regularizer',
#  '_add_trackable',
#  '_add_trackable_child',
#  '_add_variable_with_custom_getter',
#  '_assert_compile_was_called',
#  '_assert_weights_created',
#  '_auto_track_sub_layers',
#  '_autocast',
#  '_autographed_call',
#  '_base_model_initialized',
#  '_build_graph_network_for_inferred_shape',
#  '_build_input_shape',
#  '_call_accepts_kwargs',
#  '_call_arg_was_passed',
#  '_call_fn_arg_defaults',
#  '_call_fn_arg_positions',
#  '_call_fn_args',
#  '_call_full_argspec',
#  '_callable_losses',
#  '_cast_single_input',
#  '_check_call_args',
#  '_checkpoint_dependencies',
#  '_clear_losses',
#  '_cluster_coordinator',
#  '_compile_was_called',
#  '_compiled_trainable_state',
#  '_compute_dtype',
#  '_compute_dtype_object',
#  '_compute_output_and_mask_jointly',
#  '_compute_tensor_usage_count',
#  '_configure_steps_per_execution',
#  '_conform_to_reference_input',
#  '_created_nodes',
#  '_dedup_weights',
#  '_default_training_arg',
#  '_deferred_dependencies',
#  '_delete_tracking',
#  '_deserialization_dependencies',
#  '_deserialize_from_proto',
#  '_distribution_strategy',
#  '_dtype',
#  '_dtype_policy',
#  '_dynamic',
#  '_eager_losses',
#  '_enable_dict_to_input_mapping',
#  '_expects_mask_arg',
#  '_expects_training_arg',
#  '_feed_input_names',
#  '_feed_input_shapes',
#  '_feed_inputs',
#  '_flatten',
#  '_flatten_layers',
#  '_flatten_modules',
#  '_flatten_to_reference_inputs',
#  '_functional_construction_call',
#  '_gather_children_attribute',
#  '_gather_saveables_for_checkpoint',
#  '_get_call_arg_value',
#  '_get_callback_model',
#  '_get_cell_name',
#  '_get_compile_args',
#  '_get_existing_metric',
#  '_get_input_masks',
#  '_get_legacy_saved_model_children',
#  '_get_node_attribute_at_index',
#  '_get_optimizer',
#  '_get_save_spec',
#  '_get_trainable_state',
#  '_graph_initialized',
#  '_graph_network_add_loss',
#  '_graph_network_add_metric',
#  '_handle_activity_regularization',
#  '_handle_deferred_dependencies',
#  '_handle_deferred_layer_dependencies',
#  '_handle_weight_regularization',
#  '_has_explicit_input_shape',
#  '_in_multi_worker_mode',
#  '_inbound_nodes',
#  '_inbound_nodes_value',
#  '_infer_output_signature',
#  '_inferred_input_shape',
#  '_init_batch_counters',
#  '_init_call_fn_args',
#  '_init_graph_network',
#  '_init_set_name',
#  '_initial_weights',
#  '_input_coordinates',
#  '_input_dtype',
#  '_input_layers',
#  '_input_spec',
#  '_insert_layers',
#  '_instrument_layer_creation',
#  '_instrumented_keras_api',
#  '_instrumented_keras_layer_class',
#  '_instrumented_keras_model_class',
#  '_is_compiled',
#  '_is_graph_network',
#  '_is_layer',
#  '_is_layer_name_unique',
#  '_is_model_for_instrumentation',
#  '_jit_compile',
#  '_keras_api_names',
#  '_keras_api_names_v1',
#  '_keras_tensor_symbolic_call',
#  '_layer_call_argspecs',
#  '_layer_checkpoint_dependencies',
#  '_list_extra_dependencies_for_serialization',
#  '_list_functions_for_serialization',
#  '_lookup_dependency',
#  '_losses',
#  '_map_resources',
#  '_maybe_build',
#  '_maybe_cast_inputs',
#  '_maybe_create_attribute',
#  '_maybe_initialize_trackable',
#  '_maybe_load_initial_epoch_from_ckpt',
#  '_metrics',
#  '_metrics_lock',
#  '_must_restore_from_config',
#  '_name',
#  '_name_based_attribute_restore',
#  '_name_based_restores',
#  '_name_scope',
#  '_nested_inputs',
#  '_nested_outputs',
#  '_network_nodes',
#  '_no_dependency',
#  '_nodes_by_depth',
#  '_non_trainable_weights',
#  '_obj_reference_counts',
#  '_obj_reference_counts_dict',
#  '_object_identifier',
#  '_outbound_nodes',
#  '_outbound_nodes_value',
#  '_outer_name_scope',
#  '_output_coordinates',
#  '_output_layers',
#  '_output_mask_cache',
#  '_output_shape_cache',
#  '_output_tensor_cache',
#  '_predict_counter',
#  '_preload_simple_restoration',
#  '_preserve_input_structure_in_config',
#  '_reset_compile_cache',
#  '_restore_from_checkpoint_position',
#  '_run_eagerly',
#  '_run_internal_graph',
#  '_saved_model_arg_spec',
#  '_saved_model_inputs_spec',
#  '_self_name_based_restores',
#  '_self_saveable_object_factories',
#  '_self_setattr_tracking',
#  '_self_tracked_trackables',
#  '_self_unconditional_checkpoint_dependencies',
#  '_self_unconditional_deferred_dependencies',
#  '_self_unconditional_dependency_names',
#  '_self_update_uid',
#  '_serialize_to_proto',
#  '_set_call_arg_value',
#  '_set_connectivity_metadata',
#  '_set_dtype_policy',
#  '_set_inputs',
#  '_set_mask_keras_history_checked',
#  '_set_mask_metadata',
#  '_set_output_names',
#  '_set_save_spec',
#  '_set_trainable_state',
#  '_set_training_mode',
#  '_setattr_tracking',
#  '_should_cast_single_input',
#  '_should_compute_mask',
#  '_should_eval',
#  '_single_restoration_from_checkpoint_position',
#  '_split_out_first_arg',
#  '_stateful',
#  '_steps_per_execution',
#  '_supports_masking',
#  '_symbolic_call',
#  '_tensor_usage_count',
#  '_test_counter',
#  '_tf_api_names',
#  '_tf_api_names_v1',
#  '_thread_local',
#  '_track_trackable',
#  '_trackable_children',
#  '_trackable_saved_model_saver',
#  '_trackable_saver',
#  '_tracking_metadata',
#  '_train_counter',
#  '_trainable',
#  '_trainable_weights',
#  '_training_state',
#  '_unconditional_checkpoint_dependencies',
#  '_unconditional_dependency_names',
#  '_undeduplicated_weights',
#  '_update_uid',
#  '_updated_config',
#  '_updates',
#  '_use_input_spec_as_call_signature',
#  '_use_legacy_deferred_behavior',
#  '_validate_compile',
#  '_validate_graph_inputs_and_outputs',
#  '_validate_target_and_loss',
#  'activity_regularizer',
#  'add',
#  'add_loss',
#  'add_metric',
#  'add_update',
#  'add_variable',
#  'add_weight',
#  'apply',
#  'build',
#  'built',
#  'call',
#  'compile',
#  'compiled_loss',
#  'compiled_metrics',
#  'compute_dtype',
#  'compute_loss',
#  'compute_mask',
#  'compute_metrics',
#  'compute_output_shape',
#  'compute_output_signature',
#  'count_params',
#  'distribute_strategy',
#  'dtype',
#  'dtype_policy',
#  'dynamic',
#  'evaluate',
#  'evaluate_generator',
#  'finalize_state',
#  'fit',
#  'fit_generator',
#  'from_config',
#  'get_config',
#  'get_input_at',
#  'get_input_mask_at',
#  'get_input_shape_at',
#  'get_layer',
#  'get_losses_for',
#  'get_output_at',
#  'get_output_mask_at',
#  'get_output_shape_at',
#  'get_updates_for',
#  'get_weights',
#  'history',
#  'inbound_nodes',
#  'input',
#  'input_mask',
#  'input_names',
#  'input_shape',
#  'input_spec',
#  'inputs',
#  'layers',
#  'load_weights',
#  'loss',
#  'losses',
#  'make_predict_function',
#  'make_test_function',
#  'make_train_function',
#  'metrics',
#  'metrics_names',
#  'name',
#  'name_scope',
#  'non_trainable_variables',
#  'non_trainable_weights',
#  'optimizer',
#  'outbound_nodes',
#  'output',
#  'output_mask',
#  'output_names',
#  'output_shape',
#  'outputs',
#  'pop',
#  'predict',
#  'predict_function',
#  'predict_generator',
#  'predict_on_batch',
#  'predict_step',
#  'reset_metrics',
#  'reset_states',
#  'run_eagerly',
#  'save',
#  'save_spec',
#  'save_weights',
#  'set_weights',
#  'state_updates',
#  'stateful',
#  'stop_training',
#  'submodules',
#  'summary',
#  'supports_masking',
#  'test_function',
#  'test_on_batch',
#  'test_step',
#  'to_json',
#  'to_yaml',
#  'train_function',
#  'train_on_batch',
#  'train_step',
#  'train_tf_function',
#  'trainable',
#  'trainable_variables',
#  'trainable_weights',
#  'updates',
#  'variable_dtype',
#  'variables',
#  'weights',
#  'with_name_scope']

# %%
# Make Epochs Vs. Training Accuracy for beest model
accs = current_best_history["accuracy"]
epochs = [i for i in range(len(accs))]

plt.plot(epochs, accs)
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.title("Training Accuracy Vs. Epoch for Best Model: HPs (Fill in later)")
plt.show()

# %%
# Make Epochs Vs. Training Loss for best model
loss = current_best_history["loss"]

plt.plot(epochs, loss)
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.title("Training Loss Vs. Epoch for Best Model: HPs (Fill in Later)")
plt.show()

# %%
# Make necessary containers for converted test images. This section will be
## basically a mirror of the .tif -> .png conversion done on the training data.
dirTestTarget = "./pngContainer/pngTest/imgs/"
#Note we require .../imgs/ so that there exists a subdirectory for keras to find
os.makedirs(dirTestTarget)
test_dir = "./test/"
test_imgs = os.listdir(test_dir)
test_imgs.sort()

for img in test_imgs:
  convertToPNG(dirTestTarget, test_dir, img)

# Make test_data as BatchDataset
test_data = tf.keras.utils.image_dataset_from_directory(
    directory = "/content/pngContainer/pngTest",
    labels = None,
    label_mode = "binary",
    color_mode = "rgb",
    image_size = (96, 96),
    batch_size = 32
)
# Out:
# Found 57458 files belonging to 1 classes.

# %%
# Make Predictions using test_data
yhat = current_best_model[0].predict(test_data)

# %%
# Finalize predictions and make csv to submit to Kaggle
yhat = yhat.reshape((yhat.shape[0], ))
label = [round(yhat[i]) for i in range(len(yhat))]
testids = test_data.file_paths
id = [testids[i][35:-4] for i in range(len(testids))]

predDic = {
    "id" : id,
    "label" : label
}
preddf = pd.DataFrame(predDic)
